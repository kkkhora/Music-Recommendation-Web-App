# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv('database.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36406 entries, 0 to 36405
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   uri               36406 non-null  object
#  1   acousticness      36406 non-null  float64
#  2   valence           36406 non-null  float64
#  3   danceability      36406 non-null  float64
#  4   energy            36406 non-null  float64
#  5   key               36406 non-null  int64
#  6   instrumentalness  36406 non-null  float64
#  7   liveness          36406 non-null  float64
#  8   loudness          36406 non-null  float64
#  9   speechiness       36406 non-null  float64
#  10  tempo             36406 non-null  float64
#  11  duration          36406 non-null  int64
#  12  h/s               36406 non-null  object
# dtypes: float64(9), int64(2), object(2)
# memory usage: 3.6+ MB

# %%
df.drop_duplicates(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25500 entries, 0 to 36405
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   uri               25500 non-null  object
#  1   acousticness      25500 non-null  float64
#  2   valence           25500 non-null  float64
#  3   danceability      25500 non-null  float64
#  4   energy            25500 non-null  float64
#  5   key               25500 non-null  int64
#  6   instrumentalness  25500 non-null  float64
#  7   liveness          25500 non-null  float64
#  8   loudness          25500 non-null  float64
#  9   speechiness       25500 non-null  float64
#  10  tempo             25500 non-null  float64
#  11  duration          25500 non-null  int64
#  12  h/s               25500 non-null  object
# dtypes: float64(9), int64(2), object(2)
# memory usage: 2.7+ MB

# %%
df = df.groupby('uri')['h/s'].nunique()

# %%
df1[df1>1]
# Out:
# uri
# spotify:track:00f9VGHfQhAHMCQ2bSjg3D    2
# spotify:track:015jLlgBeSkl3CApWJhlv7    2
# spotify:track:018pMkBnWM0DBeH1ChL06R    2
# spotify:track:01Q3OyB05mLgH01fpdAMPP    2
# spotify:track:01k24g94i1JvkFLQmVEdCd    2
#                                        ..
# spotify:track:7ycWLEP1GsNjVvcjawXz3z    2
# spotify:track:7ytR5pFWmSjzHJIeQkgog4    2
# spotify:track:7yws3pF3FFguwT2Psi6c15    2
# spotify:track:7ywzEdEuVG1lsjsRCGJfLy    2
# spotify:track:7z73ehYAn9O1XP9XlCqVtd    2
# Name: h/s, Length: 1492, dtype: int64

# %%
uni_uri = df1[df1>1]

# %%
type(uni_uri)
# Out:
# pandas.core.series.Series

# %%
list(uni_uri.index)
# Out:
# ['spotify:track:00f9VGHfQhAHMCQ2bSjg3D',
#  'spotify:track:015jLlgBeSkl3CApWJhlv7',
#  'spotify:track:018pMkBnWM0DBeH1ChL06R',
#  'spotify:track:01Q3OyB05mLgH01fpdAMPP',
#  'spotify:track:01k24g94i1JvkFLQmVEdCd',
#  'spotify:track:01uqI4H13Gsd8Lyl1EYd8H',
#  'spotify:track:023H4I7HJnxRqsc9cqeFKV',
#  'spotify:track:02WacdrRpm4zlP8H7X6bnQ',
#  'spotify:track:02Ygu8lo3qSknRpcBnspso',
#  'spotify:track:02kDW379Yfd5PzW5A6vuGt',
#  'spotify:track:02tvc9CFnTyHuSRlGeNv9w',
#  'spotify:track:03mMSLEJCPoGJwQhHpN5y0',
#  'spotify:track:047fCsbO4NdmwCBn8pcUXl',
#  'spotify:track:05CrK6Q5VGtfPDtyQFJ4Kf',
#  'spotify:track:05lBuZWQ2OhQuzoCSIkvUF',
#  'spotify:track:05wIrZSwuaVWhcv5FfqeH0',
#  'spotify:track:063NZb2yhsUnk2nDdng74c',
#  'spotify:track:06u5LrUpbosQlQ1QJFhPpG',
#  'spotify:track:07FkzikE6FuHIa8Ma7zJGc',
#  'spotify:track:07KXEDMj78x68D884wgVEm',
#  'spotify:track:07q0QVgO56EorrSGHC48y3',
#  'spotify:track:07zL0LP8Xt2CCM8MXA5PJh',
#  'spotify:track:08bNPGLD8AhKpnnERrAc6G',
# ...

# %%
df2 = df[df['uri'].isin(list(uni_uri.index))]

# %%
df2['h/s'] = 'h'

# %%
df2.drop_duplicates(inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1493 entries, 20 to 26438
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   uri               1493 non-null   object
#  1   acousticness      1493 non-null   float64
#  2   valence           1493 non-null   float64
#  3   danceability      1493 non-null   float64
#  4   energy            1493 non-null   float64
#  5   key               1493 non-null   int64
#  6   instrumentalness  1493 non-null   float64
#  7   liveness          1493 non-null   float64
#  8   loudness          1493 non-null   float64
#  9   speechiness       1493 non-null   float64
#  10  tempo             1493 non-null   float64
#  11  duration          1493 non-null   int64
#  12  h/s               1493 non-null   object
# dtypes: float64(9), int64(2), object(2)
# memory usage: 163.3+ KB

# %%
df3 = df[~df['uri'].isin(list(uni_uri.index))]

# %%
df1 = pd.concat([df2,df3])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24009 entries, 20 to 36405
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   uri               24009 non-null  object
#  1   acousticness      24009 non-null  float64
#  2   valence           24009 non-null  float64
#  3   danceability      24009 non-null  float64
#  4   energy            24009 non-null  float64
#  5   key               24009 non-null  int64
#  6   instrumentalness  24009 non-null  float64
#  7   liveness          24009 non-null  float64
#  8   loudness          24009 non-null  float64
#  9   speechiness       24009 non-null  float64
#  10  tempo             24009 non-null  float64
#  11  duration          24009 non-null  int64
#  12  h/s               24009 non-null  object
# dtypes: float64(9), int64(2), object(2)
# memory usage: 2.6+ MB

# %%
df1[df1['uri'] == 'spotify:track:7z73ehYAn9O1XP9XlCqVtd']
# Out:
#                                        uri  acousticness  valence  \
# 6304  spotify:track:7z73ehYAn9O1XP9XlCqVtd       0.00683    0.625
#
#       danceability  energy  key  instrumentalness  liveness  loudness  \
# 6304         0.719   0.616    1          0.000031    0.0742    -3.951
#
#       speechiness    tempo  duration h/s
# 6304       0.0395  124.963    200880   h

# %%
df1.to_csv("dataset_dedupe.csv")
